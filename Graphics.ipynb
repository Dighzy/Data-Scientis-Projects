# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as srn

# %%
dados = pd.read_csv("dados.csv", sep=";")
dados
# Out:
#      CODIGO                MUNICIPIO       PIB  VALOREMPENHO
# 0       106    SANTANA DO LIVRAMENTO  12240.76    1088666.10
# 1       113             SANTO ANGELO  16575.82     800669.92
# 2       118   SAO FRANCISCO DE ASSIS  12037.61     466122.80
# 3        13          CACAPAVA DO SUL  13674.54     485535.86
# 4       120              SAO GABRIEL  19912.38     533719.86
# ..      ...                      ...       ...           ...
# 182     372  SANTA VITORIA DO PALMAR  27170.89        760.00
# 183     107     SANTA BARBARA DO SUL  29654.02        365.00
# 184      54           GETULIO VARGAS  16876.33        233.01
# 185     382          NOVA SANTA RITA  25938.38        310.58
# 186      60      GUARANI DAS MISSOES  24363.31        172.13
#
# [187 rows x 4 columns]

# %%
srn.histplot(dados.VALOREMPENHO, color="blue", kde=False, stat="count", bins=16).set(title='Volume')
# Out:
# [Text(0.5, 1.0, 'Volume')]

# %%
srn.boxplot(data = dados ,orient='h')
# Out:
# <AxesSubplot:>

# %%
srn.boxplot(data = dados.VALOREMPENHO ,orient='h').set(title = "Pib")
# Out:
# [Text(0.5, 1.0, 'Pib')]

# %%
plt.scatter(dados.PIB, dados.MUNICIPIO)

# %%
agrupado = dados.sort_values('PIB').head(10)
agrupado = agrupado.iloc[:,[1,3]]

agrupado
agrupado.plot.bar(x='MUNICIPIO',y='VALOREMPENHO', color = 'gray')
# Out:
# <AxesSubplot:xlabel='MUNICIPIO'>

# %%
agrupado = dados.sort_values('VALOREMPENHO').head(10)

agrupado = agrupado.iloc[:,[1,3]]
agrupado


agrupado.plot.bar(x='MUNICIPIO',y='VALOREMPENHO', color = 'gray')
# Out:
# <AxesSubplot:xlabel='MUNICIPIO'>

# %%
#visualição sem o iloc ( sem retirar dados não necessesarios)
agrupado = dados.sort_values('PIB').head(10)
agrupado
# Out:
#     CODIGO             MUNICIPIO       PIB  VALOREMPENHO
# 88     216             REDENTORA   8236.63      60134.00
# 11     248       AMARAL FERRADOR   9216.87     235327.02
# 15      38   ENCRUZILHADA DO SUL  10372.80     200738.61
# 66     414      SENTINELA DO SUL  10477.52      92380.20
# 89     413    SAO VALERIO DO SUL  10503.72      67638.25
# 6       95              PIRATINI  10811.67     315884.50
# 56     204                  MATA  10935.82     107740.90
# 37     222  SANTANA DA BOA VISTA  11172.34     139594.29
# 16      23               CANGUCU  11213.34     205741.65
# 47     288             JAQUIRANA  11413.37     129434.42

# %%
#Usando o iloc e deixando somente pib e municipio
agrupado = dados.sort_values('PIB').head(10)

agrupado = agrupado.iloc[:,1:3] # de todos os valores : ele quer o valor 2 até 3 1:3 // o ele ira contar um numero pra frente caso queira o 1 coloque 0 
agrupado
# Out:
#                MUNICIPIO       PIB
# 88             REDENTORA   8236.63
# 11       AMARAL FERRADOR   9216.87
# 15   ENCRUZILHADA DO SUL  10372.80
# 66      SENTINELA DO SUL  10477.52
# 89    SAO VALERIO DO SUL  10503.72
# 6               PIRATINI  10811.67
# 56                  MATA  10935.82
# 37  SANTANA DA BOA VISTA  11172.34
# 16               CANGUCU  11213.34
# 47             JAQUIRANA  11413.37

# %%
#visualição sem o iloc ( sem retirar dados não necessesarios)
agrupado = dados.sort_values('VALOREMPENHO').head(10)

agrupado
# Out:
#      CODIGO                MUNICIPIO       PIB  VALOREMPENHO
# 186      60      GUARANI DAS MISSOES  24363.31        172.13
# 184      54           GETULIO VARGAS  16876.33        233.01
# 185     382          NOVA SANTA RITA  25938.38        310.58
# 183     107     SANTA BARBARA DO SUL  29654.02        365.00
# 182     372  SANTA VITORIA DO PALMAR  27170.89        760.00
# 181     372              MATO LEITAO  27170.89        760.00
# 180     372  SANTA VITORIA DO PALMAR  17213.98        760.00
# 179     372              MATO LEITAO  17213.98        760.00
# 178     129                 SAO SEPE  15525.66       1186.00
# 177      65                     IJUI  23027.95       5920.00

# %%
#Usando o iloc e deixando somente municipio e valorempenho
agrupado = dados.sort_values('VALOREMPENHO').head(10) # todos os itens das linhas : ( todos ) o valor 1 e 3  [1,3]
agrupado = agrupado.iloc[:,[1,3]]

agrupado
# Out:
#                    MUNICIPIO  VALOREMPENHO
# 186      GUARANI DAS MISSOES        172.13
# 184           GETULIO VARGAS        233.01
# 185          NOVA SANTA RITA        310.58
# 183     SANTA BARBARA DO SUL        365.00
# 182  SANTA VITORIA DO PALMAR        760.00
# 181              MATO LEITAO        760.00
# 180  SANTA VITORIA DO PALMAR        760.00
# 179              MATO LEITAO        760.00
# 178                 SAO SEPE       1186.00
# 177                     IJUI       5920.00
